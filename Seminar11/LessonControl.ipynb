# %% [raw]
# f(x) = -12*x**4*sin(cos(x))-18*x**3+5*x**2+10*x-30
# Определить корни
# Найти интервалы, на которых функция возрастает
# Найти интервалы, на которых функция убывает
# Построить график
# Вычислить вершину
# Определить промежутки, на котором f > 0
# Определить промежутки, на котором f < 0

# %%
import matplotlib.pyplot as plt
from sympy import *
import math

# %% [markdown]
# 1. *__Определить корни__*

# %%
x = Symbol('x')
f = [-12*x**4*sin(cos(x))-18*x**3+5*x**2+10*x-30 for x in range(-200,201)]
solve(x, f)
# Out:
# []

# %% [markdown]
# ## Так как функция в таком виде, там бесконечное чилсло корней,
# ### на графике ниже предоставлен

# %% [markdown]
# 2. *__Найти интервалы, на которых функция возраста__*

# %% [markdown]
# * На отезке от -200 до 200 показано что чем лиже график движется к 0 тем меньше у нее рост но частота возрастания и убывания не изменяется

# %% [markdown]
# 3. *__Найти интервалы, на которых функция убывает__*

# %% [markdown]
# 4. *__Построить график__*

# %%
plt.plot (f)

# %% [markdown]
# 5. *__Вычислить вершину__*

# %% [markdown]
# * По формуле и графику видно что вершин очень много и чем ближе к 0 тем вершина каждого отрезка уменьшается

# %% [markdown]
# 6. *__Определить промежутки, на котором f > 0__*

# %% [markdown]
# 7. *__Определить промежутки, на котором f < 0__*
